# %%
#A1
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

data = pd.read_excel('/content/Malayalam_Char_Gabor.xlsx')

features = data[['Theta0_Lambda1_LocalEnergy', 'Theta0_Lambda0_LocalEnergy']]
target = data['ImageName']

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

clf = SVC()
clf.fit(X_train, y_train)

support_vectors = clf.support_vectors_

print(f'Support Vectors ={support_vectors}')
# Out:
# Support Vectors =[[ 63716.  44338.]
#  [115412.  84255.]
#  [ 52393.  50575.]
#  ...
#  [ 98012.  72826.]
#  [     0.      0.]
#  [ 61134.  42780.]]

# %%
#A2

accuracy = clf.score(X_test[['Theta0_Lambda1_LocalEnergy', 'Theta0_Lambda0_LocalEnergy']], y_test)
print(f"Accuracy of the SVM on the test set: {accuracy}")

test_vector = X_test[['Theta0_Lambda1_LocalEnergy', 'Theta0_Lambda0_LocalEnergy']].iloc[0]
predicted_class = clf.predict([test_vector])
print(f"The predicted class for the test vector: {predicted_class}")
# Out:
# Accuracy of the SVM on the test set: 0.0018404907975460123
# The predicted class for the test vector: ['23.png']
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
#A3
features = data[['Theta0_Lambda1_LocalEnergy', 'Theta0_Lambda0_LocalEnergy']]
target = data['ImageName']

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

predictions = clf.predict(X_test)
print("Predictions:", predictions)

for i, prediction in enumerate(predictions):
    print(f"Sample {i + 1}: Predicted class {prediction}")

accuracy = sum(predictions == y_test) / len(y_test)
print("Accuracy:", accuracy)
# Out:
# Predictions: ['23.png' '65.png' '52.png' ... '23.png' '71.png' '88.png']
# Sample 1: Predicted class 23.png
# Sample 2: Predicted class 65.png
# Sample 3: Predicted class 52.png
# Sample 4: Predicted class 93.png
# Sample 5: Predicted class 23.png
# Sample 6: Predicted class 52.png
# Sample 7: Predicted class 2.png
# Sample 8: Predicted class 54.png
# Sample 9: Predicted class 23.png
# Sample 10: Predicted class 54.png
# Sample 11: Predicted class 85.png
# Sample 12: Predicted class 23.png
# Sample 13: Predicted class 2.png
# Sample 14: Predicted class 2.png
# Sample 15: Predicted class 71.png
# Sample 16: Predicted class 23.png
# Sample 17: Predicted class 2.png
# Sample 18: Predicted class 54.png
# Sample 19: Predicted class 2.png
# Sample 20: Predicted class 93.png
# Sample 21: Predicted class 71.png
# Sample 22: Predicted class 85.png
# Sample 23: Predicted class 85.png
# Sample 24: Predicted class 54.png
# Sample 25: Predicted class 2.png
# Sample 26: Predicted class 71.png
# ...

# %%
#A4
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

features = data[['Theta0_Lambda1_LocalEnergy', 'Theta0_Lambda0_LocalEnergy']]
target = data['ImageName']

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

kernel_functions = ['linear', 'poly', 'rbf', 'sigmoid']

for kernel in kernel_functions:

    clf = svm.SVC(kernel=kernel)
    clf.fit(X_train, y_train)


    y_pred = clf.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)
    print(f"Kernel: {kernel}, Accuracy: {accuracy * 100:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a4091b3b6074> in <cell line: 6>()
#       4 from sklearn.metrics import accuracy_score
#       5
# ----> 6 features = data[['Theta0_Lambda1_LocalEnergy', 'Theta0_Lambda0_LocalEnergy']]
#       7 target = data['ImageName']
#       8
#
# NameError: name 'data' is not defined
